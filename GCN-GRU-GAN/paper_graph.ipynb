# %%
import utils
import matplotlib.pyplot as plt

start='2016-01-02'
end='2017-01-02'
for site in ['合作金融大厦']:
    seqs_normal, adj, node_f, nks, conns, target_map, area_seqs  = utils.init_data(site, start, end, graph_nodes_max_dis = 0.5)
    plt.rc('font', size=20)
    # plt.grid(True)
    fig, axe = plt.subplots()
    fig.set_figheight(8)
    fig.set_figwidth(20)
    seqs_normal.take(range(96 * 7 * 0, 96 * 7 * 1)).plot(ax=axe, linewidth=3, alpha=0.8)
    n = 2
    # ax.legend(['real' + str(w) for w in range(1, n)] + ['gen' + str(w) for w in range(1, n)])
    axe.legend(['Huarunwanxiang Building','City Famous Park','Jingfeng Building'], fontsize=25)
    axe.set_ylabel('Occupied Parking Space Rate', fontsize=25)
    axe.set_xlabel('Time Point', fontsize=25)
    axe.xaxis.set_tick_params(rotation=10, size=15)
    axe.xaxis.set_ticks_position('top')
    # axe.set_xticklabels(seqs_normal[0][::96], rotation=45)
    # fig.savefig(save_path + "/compare_" + str(name) + ".png")
    # plt.close()
# Out:
# INFO:tensorflow:Using local port 22733
# INFO:tensorflow:Using local port 24323
# INFO:tensorflow:Using local port 18628
# INFO:tensorflow:Using local port 22017
# INFO:tensorflow:Using local port 21234
# INFO:tensorflow:Using local port 19680
# INFO:tensorflow:Using local port 20766
# INFO:tensorflow:Using local port 18447
# INFO:tensorflow:Using local port 16316
# INFO:tensorflow:Using local port 19744
# 2016-08-31 17:45:00 2017-01-02

# %%
target_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrap
# ...

# %%
nks
# Out:
# {'东门天地大厦': 0}

# %%
plt.rc('font', size=20)
# plt.grid(True)
fig, axe = plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(20)
#seqs_normal.take(range(96 * 7 * 0, 96 * 7 * 10))[0].plot(ax=axe, linewidth=3, alpha=0.8)
seqs_normal.take(range(20400, 22700))[0].plot(ax=axe, linewidth=3, alpha=0.8)

n = 2
# ax.legend(['real' + str(w) for w in range(1, n)] + ['gen' + str(w) for w in range(1, n)])
axe.legend(['North Lianhua Village'], fontsize=25) # 'Huarunwanxiang Building','City Famous Park','Jingfeng Building'
axe.set_ylabel('Occupied Parking Space Rate', fontsize=25)
axe.set_xlabel('Time Point', fontsize=25)
axe.xaxis.set_tick_params(rotation=20)
plt.ylim(ymin = 0)
plt.ylim(ymax = 1)
# axe.set_xticklabels(seqs_normal[0][::96], rotation=45)
# fig.savefig(save_path + "/compare_" + str(name) + ".png")
# plt.close()
# Out:
# (0.0, 1.0)

# %%
conns
# Out:
# [['丽晶大厦', '华安国际大酒店', 0.607417325986913],
#  ['丽晶大厦', '华润万象城', 0.2919517862258945],
#  ['丽晶大厦', '华瑞大厦', 0.41800661872101796],
#  ['丽晶大厦', '都市名园', 0.16257362020433205],
#  ['丽晶大厦', '金丰城', 0.3213992619480776],
#  ['丽晶大厦', '金山大厦', 0.2498684536186296],
#  ['丽晶大厦', '金融中心', 0.07800565256046557],
#  ['华安国际大酒店', '丽晶大厦', 0.607417325986913],
#  ['华安国际大酒店', '华润万象城', 0.4879545135940463],
#  ['华安国际大酒店', '华瑞大厦', 0.8849602836167628],
#  ['华安国际大酒店', '都市名园', 0.4774111556575397],
#  ['华安国际大酒店', '金丰城', 0.3457263217557794],
#  ['华安国际大酒店', '金山大厦', 0.3742832564635014],
#  ['华安国际大酒店', '金融中心', 0.6357305607243137],
#  ['华润万象城', '丽晶大厦', 0.2919517862258945],
#  ['华润万象城', '华安国际大酒店', 0.4879545135940463],
#  ['华润万象城', '华瑞大厦', 0.39927579488455345],
#  ['华润万象城', '都市名园', 0.15073484996897937],
#  ['华润万象城', '金丰城', 0.14637921565664525],
#  ['华润万象城', '金山大厦', 0.1727248257750685],
#  ['华润万象城', '金融中心', 0.3663566650961904],
#  ['华瑞大厦', '丽晶大厦', 0.41800661872101796],
#  ['华瑞大厦', '华安国际大酒店', 0.8849602836167628],
# ...

# %%
area_seqs.to_csv('building features.csv')

# %%
nks
# Out:
# {'东门天地大厦': 0, '嘉年华名苑': 1}

# %%
seqs_normal
# Out:
# parking                     0         1
# date
# 2016-07-01 18:45:00  0.429630  0.245902
# 2016-07-01 19:00:00  0.432099  0.286885
# 2016-07-01 19:15:00  0.429630  0.303279
# 2016-07-01 19:30:00  0.437037  0.319672
# 2016-07-01 19:45:00  0.466667  0.336066
# ...                       ...       ...
# 2016-10-28 06:45:00  0.920988  0.221311
# 2016-10-28 07:00:00  0.913580  0.188525
# 2016-10-28 07:15:00  0.903704  0.155738
# 2016-10-28 07:30:00  0.886420  0.081967
# 2016-10-28 07:45:00  0.861728  0.008197
#
# [11381 rows x 2 columns]
