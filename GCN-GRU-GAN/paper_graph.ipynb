# %%
import utils
import matplotlib.pyplot as plt

start='2016-01-02'
end='2017-01-02'
for site in ['华润万象城']:
    seqs_normal, adj, node_f, nks, conns, target_map  = utils.init_data(site, start, end, graph_nodes_max_dis = 0.17)
    plt.rc('font', size=20)
    # plt.grid(True)
    fig, axe = plt.subplots()
    fig.set_figheight(8)
    fig.set_figwidth(20)
    seqs_normal.take(range(96 * 7 * 0, 96 * 7 * 1)).plot(ax=axe, linewidth=3, alpha=0.8)
    n = 2
    # ax.legend(['real' + str(w) for w in range(1, n)] + ['gen' + str(w) for w in range(1, n)])
    axe.legend(['Huarunwanxiang Building','City Famous Park','Jingfeng Building'], fontsize=25)
    axe.set_ylabel('Occupied Parking Space Rate', fontsize=25)
    axe.set_xlabel('Time Point', fontsize=25)
    axe.xaxis.set_tick_params(rotation=10, size=15)
    axe.xaxis.set_ticks_position('top')
    # axe.set_xticklabels(seqs_normal[0][::96], rotation=45)
    # fig.savefig(save_path + "/compare_" + str(name) + ".png")
    # plt.close()

# %%
target_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css%22/%3E%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_ea27d9eb7dd74738bb59d9da8391fec9%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_ea27d9eb7dd74738bb59d9da8391fec9%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_ea27d9eb7dd74738bb59d9da8391fec9%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_ea27d9eb7dd74738bb59d9da8391fec9%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B22.542234%2C%20114.105075%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20% ...

# %%
nks
# Out:
# {'华润万象城': 0, '都市名园': 1, '金丰城': 2}

# %%
plt.rc('font', size=20)
# plt.grid(True)
fig, axe = plt.subplots()
fig.set_figheight(8)
fig.set_figwidth(20)
seqs_normal.take(range(96 * 7 * 0, 96 * 7 * 1))[2].plot(ax=axe, linewidth=3, alpha=0.8)
n = 2
# ax.legend(['real' + str(w) for w in range(1, n)] + ['gen' + str(w) for w in range(1, n)])
axe.legend(['Jingfeng Building'], fontsize=25) # 'Huarunwanxiang Building','City Famous Park','Jingfeng Building'
axe.set_ylabel('Occupied Parking Space Rate', fontsize=25)
axe.set_xlabel('Time Point', fontsize=25)
axe.xaxis.set_tick_params(rotation=30)
# axe.set_xticklabels(seqs_normal[0][::96], rotation=45)
# fig.savefig(save_path + "/compare_" + str(name) + ".png")
# plt.close()

# %%
conns
# Out:
# [['华润万象城', '都市名园', 0.15073484996897937],
#  ['华润万象城', '金丰城', 0.14637921565664525],
#  ['都市名园', '华润万象城', 0.15073484996897937],
#  ['都市名园', '金丰城', 0.16100497353401563],
#  ['金丰城', '华润万象城', 0.14637921565664525],
#  ['金丰城', '都市名园', 0.16100497353401563]]

# %%
df
# Out:
#    a  b
# 0  2  4
# 1  3  5
# 2  4  6
